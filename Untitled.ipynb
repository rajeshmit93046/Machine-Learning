# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Data fetching

# %%
df=pd.read_csv("train.csv")
df2=pd.read_csv("test.csv")

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.drop(['Name','PassengerId'],axis=1,inplace=True)
df
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch            Ticket     Fare  \
# 0           0       3    male  22.0      1      0         A/5 21171   7.2500
# 1           1       1  female  38.0      1      0          PC 17599  71.2833
# 2           1       3  female  26.0      0      0  STON/O2. 3101282   7.9250
# 3           1       1  female  35.0      1      0            113803  53.1000
# 4           0       3    male  35.0      0      0            373450   8.0500
# ..        ...     ...     ...   ...    ...    ...               ...      ...
# 886         0       2    male  27.0      0      0            211536  13.0000
# 887         1       1  female  19.0      0      0            112053  30.0000
# 888         0       3  female   NaN      1      2        W./C. 6607  23.4500
# 889         1       1    male  26.0      0      0            111369  30.0000
# 890         0       3    male  32.0      0      0            370376   7.7500
#
#     Cabin Embarked
# 0     NaN        S
# 1     C85        C
# 2     NaN        S
# 3    C123        S
# 4     NaN        S
# ..    ...      ...
# 886   NaN        S
# 887   B42        S
# 888   NaN        S
# 889  C148        C
# 890   NaN        Q
#
# [891 rows x 10 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Sex       891 non-null    object
#  3   Age       714 non-null    float64
#  4   SibSp     891 non-null    int64
#  5   Parch     891 non-null    int64
#  6   Ticket    891 non-null    object
#  7   Fare      891 non-null    float64
#  8   Cabin     204 non-null    object
#  9   Embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(4)
# memory usage: 69.7+ KB

# %%
df.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df.isna().sum()
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %%
x=df.iloc[:,1:].values
y=df.iloc[:,0].values

# %%
df2=df.copy()
df2.isnull().sum()
df2.shape
# Out:
# (891, 10)

# %%
df2.dropna(inplace=True)
print(df2.isnull().sum())
df.shape
# Out:
# Survived    0
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Ticket      0
# Fare        0
# Cabin       0
# Embarked    0
# dtype: int64
# (891, 10)

# %%
df3=df.copy()

# %%
df3.fillna(df.mean,inplace=True)
print(df3.shape)
print(df3.isnull().sum())
df3
# Out:
# (891, 10)
# Survived    0
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Ticket      0
# Fare        0
# Cabin       0
# Embarked    0
# dtype: int64
#      Survived  Pclass     Sex  \
# 0           0       3    male
# 1           1       1  female
# 2           1       3  female
# 3           1       1  female
# 4           0       3    male
# ..        ...     ...     ...
# 886         0       2    male
# 887         1       1  female
# 888         0       3  female
# 889         1       1    male
# 890         0       3    male
#
#                                                    Age  SibSp  Parch  \
# 0                                                 22.0      1      0
# 1                                                 38.0      1      0
# 2                                                 26.0      0      0
# 3                                                 35.0      1      0
# 4                                                 35.0      0      0
# ..                                                 ...    ...    ...
# 886                                               27.0      0      0
# 887                                               19.0      0      0
# 888  <bound method NDFrame._add_numeric_operations....      1      2
# 889                                               26.0      0      0
# 890                                               32.0      0      0
#
#                Ticket     Fare  \
# 0           A/5 21171   7.2500
# 1            PC 17599  71.2833
# 2    STON/O2. 3101282   7.9250
# 3              113803  53.1000
# 4              373450   8.0500
# ..                ...      ...
# 886            211536  13.0000
# 887            112053  30.0000
# 888        W./C. 6607  23.4500
# 889            111369  30.0000
# 890            370376   7.7500
#
#                                                  Cabin Embarked
# 0    <bound method NDFrame._add_numeric_operations....        S
# 1                                                  C85        C
# 2    <bound method NDFrame._add_numeric_operations....        S
# 3                                                 C123        S
# 4    <bound method NDFrame._add_numeric_operations....        S
# ..                                                 ...      ...
# 886  <bound method NDFrame._add_numeric_operations....        S
# 887                                                B42        S
# 888  <bound method NDFrame._add_numeric_operations....        S
# 889                                               C148        C
# 890  <bound method NDFrame._add_numeric_operations....        Q
#
# [891 rows x 10 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\formatters.py:708, in PlainTextFormatter.__call__(self, obj)
#     701 stream = StringIO()
#     702 printer = pretty.RepresentationPrinter(stream, self.verbose,
#     703     self.max_width, self.newline,
#     704     max_seq_length=self.max_seq_length,
#     705     singleton_pprinters=self.singleton_printers,
#     706     type_pprinters=self.type_printers,
#     707     deferred_pprinters=self.deferred_printers)
# --> 708 printer.pretty(obj)
#     709 printer.flush()
#     710 return stream.getvalue()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\lib\pretty.py:410, in RepresentationPrinter.pretty(self, obj)
#     407                         return meth(obj, self, cycle)
#     408                 if cls is not object \
#     409                         and callable(cls.__dict__.get('__repr__')):
# --> 410                     return _repr_pprint(obj, self, cycle)
#     412     return _default_pprint(obj, self, cycle)
#     413 finally:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\lib\pretty.py:778, in _repr_pprint(obj, p, cycle)
#     776 """A pprint that just redirects to the normal repr function."""
#     777 # Find newlines and replace them with p.break_()
# --> 778 output = repr(obj)
#     779 lines = output.splitlines()
#     780 with p.group():
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:1064, in DataFrame.__repr__(self)
#    1061     return buf.getvalue()
#    1063 repr_params = fmt.get_dataframe_repr_params()
# -> 1064 return self.to_string(**repr_params)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:1245, in DataFrame.to_string(self, buf, columns, col_space, header, index, na_rep, formatters, float_format, sparsify, index_names, justify, max_rows, max_cols, show_dimensions, decimal, line_width, min_rows, max_colwidth, encoding)
#    1226 with option_context("display.max_colwidth", max_colwidth):
#    1227     formatter = fmt.DataFrameFormatter(
#    1228         self,
#    1229         columns=columns,
#    (...)
#    1243         decimal=decimal,
#    1244     )
# -> 1245     return fmt.DataFrameRenderer(formatter).to_string(
#    1246         buf=buf,
#    1247         encoding=encoding,
#    1248         line_width=line_width,
#    1249     )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\formats\format.py:1136, in DataFrameRenderer.to_string(self, buf, encoding, line_width)
#    1133 from pandas.io.formats.string import StringFormatter
#    1135 string_formatter = StringFormatter(self.fmt, line_width=line_width)
# -> 1136 string = string_formatter.to_string()
#    1137 return save_to_buffer(string, buf=buf, encoding=encoding)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\formats\string.py:30, in StringFormatter.to_string(self)
#      29 def to_string(self) -> str:
# ---> 30     text = self._get_string_representation()
#      31     if self.fmt.should_show_dimensions:
#      32         text = "".join([text, self.fmt.dimensions_info])
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\formats\string.py:45, in StringFormatter._get_string_representation(self)
#      42 if self.fmt.frame.empty:
#      43     return self._empty_info_line
# ---> 45 strcols = self._get_strcols()
#      47 if self.line_width is None:
#      48     # no need to wrap around just print the whole frame
#      49     return self.adj.adjoin(1, *strcols)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\formats\string.py:36, in StringFormatter._get_strcols(self)
#      35 def _get_strcols(self) -> list[list[str]]:
# ---> 36     strcols = self.fmt.get_strcols()
#      37     if self.fmt.is_truncated:
#      38         strcols = self._insert_dot_separators(strcols)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\formats\format.py:617, in DataFrameFormatter.get_strcols(self)
#     613 def get_strcols(self) -> list[list[str]]:
#     614     """
#     615     Render a DataFrame to a list of columns (as lists of strings).
#     616     """
# --> 617     strcols = self._get_strcols_without_index()
#     619     if self.index:
#     620         str_index = self._get_formatted_index(self.tr_frame)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\formats\format.py:883, in DataFrameFormatter._get_strcols_without_index(self)
#     879 cheader = str_columns[i]
#     880 header_colwidth = max(
#     881     int(self.col_space.get(c, 0)), *(self.adj.len(x) for x in cheader)
#     882 )
# --> 883 fmt_values = self.format_col(i)
#     884 fmt_values = _make_fixed_width(
#     885     fmt_values, self.justify, minimum=header_colwidth, adj=self.adj
#     886 )
#     888 max_len = max(max(self.adj.len(x) for x in fmt_values), header_colwidth)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\formats\format.py:897, in DataFrameFormatter.format_col(self, i)
#     895 frame = self.tr_frame
#     896 formatter = self._get_formatter(i)
# --> 897 return format_array(
#     898     frame.iloc[:, i]._values,
#     899     formatter,
#     900     float_format=self.float_format,
#     901     na_rep=self.na_rep,
#     902     space=self.col_space.get(frame.columns[i]),
#     903     decimal=self.decimal,
#     904     leading_space=self.index,
#     905 )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\formats\format.py:1328, in format_array(values, formatter, float_format, na_rep, digits, space, justify, decimal, leading_space, quoting)
#    1313     digits = get_option("display.precision")
#    1315 fmt_obj = fmt_klass(
#    1316     values,
#    1317     digits=digits,
#    (...)
#    1325     quoting=quoting,
#    1326 )
# -> 1328 return fmt_obj.get_result()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\formats\format.py:1359, in GenericArrayFormatter.get_result(self)
#    1358 def get_result(self) -> list[str]:
# -> 1359     fmt_values = self._format_strings()
#    1360     return _make_fixed_width(fmt_values, self.justify)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\formats\format.py:1422, in GenericArrayFormatter._format_strings(self)
#    1420 for i, v in enumerate(vals):
#    1421     if not is_float_type[i] and leading_space:
# -> 1422         fmt_values.append(f" {_format(v)}")
#    1423     elif is_float_type[i]:
#    1424         fmt_values.append(float_format(v))
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\formats\format.py:1402, in GenericArrayFormatter._format_strings.<locals>._format(x)
#    1399     return str(x)
#    1400 else:
#    1401     # object dtype
# -> 1402     return str(formatter(x))
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\formats\printing.py:232, in pprint_thing(thing, _nest_lvl, escape_chars, default_escapes, quote_strings, max_seq_items)
#     230     result = f"'{as_escaped_string(thing)}'"
#     231 else:
# --> 232     result = as_escaped_string(thing)
#     234 return result
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\formats\printing.py:208, in pprint_thing.<locals>.as_escaped_string(thing, escape_chars)
#     205 else:
#     206     escape_chars = escape_chars or ()
# --> 208 result = str(thing)
#     209 for c in escape_chars:
#     210     result = result.replace(c, translate[c])
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:1064, in DataFrame.__repr__(self)
#    1061     return buf.getvalue()
#    1063 repr_params = fmt.get_dataframe_repr_params()
# -> 1064 return self.to_string(**repr_params)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:1245, in DataFrame.to_string(self, buf, columns, col_space, header, index, na_rep, formatters, float_format, sparsify, index_names, justify, max_rows, max_cols, show_dimensions, decimal, line_width, min_rows, max_colwidth, encoding)
#    1226 with option_context("display.max_colwidth", max_colwidth):
#    1227     formatter = fmt.DataFrameFormatter(
#    1228         self,
#    1229         columns=columns,
#    (...)
#    1243         decimal=decimal,
#    1244     )
# -> 1245     return fmt.DataFrameRenderer(formatter).to_string(
#    1246         buf=buf,
#    1247         encoding=encoding,
#    1248         line_width=line_width,
#    1249     )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\formats\format.py:1136, in DataFrameRenderer.to_string(self, buf, encoding, line_width)
#    1133 from pandas.io.formats.string import StringFormatter
#    1135 string_formatter = StringFormatter(self.fmt, line_width=line_width)
# -> 1136 string = string_formatter.to_string()
#    1137 return save_to_buffer(string, buf=buf, encoding=encoding)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\formats\string.py:30, in StringFormatter.to_string(self)
#      29 def to_string(self) -> str:
# ---> 30     text = self._get_string_representation()
#      31     if self.fmt.should_show_dimensions:
#      32         text = "".join([text, self.fmt.dimensions_info])
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\formats\string.py:45, in StringFormatter._get_string_representation(self)
#      42 if self.fmt.frame.empty:
#      43     return self._empty_info_line
# ---> 45 strcols = self._get_strcols()
#      47 if self.line_width is None:
#      48     # no need to wrap around just print the whole frame
#      49     return self.adj.adjoin(1, *strcols)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\formats\string.py:36, in StringFormatter._get_strcols(self)
#      35 def _get_strcols(self) -> list[list[str]]:
# ---> 36     strcols = self.fmt.get_strcols()
#      37     if self.fmt.is_truncated:
#      38         strcols = self._insert_dot_separators(strcols)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\formats\format.py:617, in DataFrameFormatter.get_strcols(self)
#     613 def get_strcols(self) -> list[list[str]]:
#     614     """
#     615     Render a DataFrame to a list of columns (as lists of strings).
#     616     """
# --> 617     strcols = self._get_strcols_without_index()
#     619     if self.index:
#     620         str_index = self._get_formatted_index(self.tr_frame)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\formats\format.py:883, in DataFrameFormatter._get_strcols_without_index(self)
#     879 cheader = str_columns[i]
#     880 header_colwidth = max(
#     881     int(self.col_space.get(c, 0)), *(self.adj.len(x) for x in cheader)
#     882 )
# --> 883 fmt_values = self.format_col(i)
#     884 fmt_values = _make_fixed_width(
#     885     fmt_values, self.justify, minimum=header_colwidth, adj=self.adj
#     886 )
#     888 max_len = max(max(self.adj.len(x) for x in fmt_values), header_colwidth)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\formats\format.py:897, in DataFrameFormatter.format_col(self, i)
#     895 frame = self.tr_frame
#     896 formatter = self._get_formatter(i)
# --> 897 return format_array(
#     898     frame.iloc[:, i]._values,
#     899     formatter,
#     900     float_format=self.float_format,
#     901     na_rep=self.na_rep,
#     902     space=self.col_space.get(frame.columns[i]),
#     903     decimal=self.decimal,
#     904     leading_space=self.index,
#     905 )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\formats\format.py:1328, in format_array(values, formatter, float_format, na_rep, digits, space, justify, decimal, leading_space, quoting)
#    1313     digits = get_option("display.precision")
#    1315 fmt_obj = fmt_klass(
#    1316     values,
#    1317     digits=digits,
#    (...)
#    1325     quoting=quoting,
#    1326 )
# -> 1328 return fmt_obj.get_result()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\formats\format.py:1359, in GenericArrayFormatter.get_result(self)
#    1358 def get_result(self) -> list[str]:
# -> 1359     fmt_values = self._format_strings()
#    1360     return _make_fixed_width(fmt_values, self.justify)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\formats\format.py:1422, in GenericArrayFormatter._format_strings(self)
#    1420 for i, v in enumerate(vals):
#    1421     if not is_float_type[i] and leading_space:
# -> 1422         fmt_values.append(f" {_format(v)}")
#    1423     elif is_float_type[i]:
#    1424         fmt_values.append(float_format(v))
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\formats\format.py:1402, in GenericArrayFormatter._format_strings.<locals>._format(x)
#    1399     return str(x)
#    1400 else:
#    1401     # object dtype
# -> 1402     return str(formatter(x))
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\formats\printing.py:232, in pprint_thing(thing, _nest_lvl, escape_chars, default_escapes, quote_strings, max_seq_items)
#     230     result = f"'{as_escaped_string(thing)}'"
#     231 else:
# --> 232     result = as_escaped_string(thing)
#     234 return result
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\formats\printing.py:208, in pprint_thing.<locals>.as_escaped_string(thing, escape_chars)
#     205 else:
#     206     escape_chars = escape_chars or ()
# --> 208 result = str(thing)
#     209 for c in escape_chars:
#     210     result = result.replace(c, translate[c])
#
#     [... skipping similar frames: DataFrame.__repr__ at line 1064 (162 times), GenericArrayFormatter._format_strings.<locals>._format at line 1402 (161 times), GenericArrayFormatter._format_strings at line 1422 (161 times), StringFormatter._get_strcols at line 36 (161 times), DataFrameFormatter._get_strcols_without_index at line 883 (161 times), StringFormatter._get_string_representation at line 45 (161 times), pprint_thing.<locals>.as_escaped_string at line 208 (161 times), format_array at line 1328 (161 times), DataFrameFormatter.format_col at line 897 (161 times), GenericArrayFormatter.get_result at line 1359 (161 times), DataFrameFormatter.get_strcols at line 617 (161 times), pprint_thing at line 232 (161 times), DataFrame.to_string at line 1245 (161 times), DataFrameRenderer.to_string at line 1136 (161 times), StringFormatter.to_string at line 30 (161 times)]
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:1245, in DataFrame.to_string(self, buf, columns, col_space, header, index, na_rep, formatters, float_format, sparsify, index_names, justify, max_rows, max_cols, show_dimensions, decimal, line_width, min_rows, max_colwidth, encoding)
#    1226 with option_context("display.max_colwidth", max_colwidth):
#    1227     formatter = fmt.DataFrameFormatter(
#    1228         self,
#    1229         columns=columns,
#    (...)
#    1243         decimal=decimal,
#    1244     )
# -> 1245     return fmt.DataFrameRenderer(formatter).to_string(
#    1246         buf=buf,
#    1247         encoding=encoding,
#    1248         line_width=line_width,
#    1249     )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\formats\format.py:1136, in DataFrameRenderer.to_string(self, buf, encoding, line_width)
#    1133 from pandas.io.formats.string import StringFormatter
#    1135 string_formatter = StringFormatter(self.fmt, line_width=line_width)
# -> 1136 string = string_formatter.to_string()
#    1137 return save_to_buffer(string, buf=buf, encoding=encoding)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\formats\string.py:30, in StringFormatter.to_string(self)
#      29 def to_string(self) -> str:
# ---> 30     text = self._get_string_representation()
#      31     if self.fmt.should_show_dimensions:
#      32         text = "".join([text, self.fmt.dimensions_info])
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\formats\string.py:45, in StringFormatter._get_string_representation(self)
#      42 if self.fmt.frame.empty:
#      43     return self._empty_info_line
# ---> 45 strcols = self._get_strcols()
#      47 if self.line_width is None:
#      48     # no need to wrap around just print the whole frame
#      49     return self.adj.adjoin(1, *strcols)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\formats\string.py:36, in StringFormatter._get_strcols(self)
#      35 def _get_strcols(self) -> list[list[str]]:
# ---> 36     strcols = self.fmt.get_strcols()
#      37     if self.fmt.is_truncated:
#      38         strcols = self._insert_dot_separators(strcols)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\formats\format.py:617, in DataFrameFormatter.get_strcols(self)
#     613 def get_strcols(self) -> list[list[str]]:
#     614     """
#     615     Render a DataFrame to a list of columns (as lists of strings).
#     616     """
# --> 617     strcols = self._get_strcols_without_index()
#     619     if self.index:
#     620         str_index = self._get_formatted_index(self.tr_frame)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\formats\format.py:883, in DataFrameFormatter._get_strcols_without_index(self)
#     879 cheader = str_columns[i]
#     880 header_colwidth = max(
#     881     int(self.col_space.get(c, 0)), *(self.adj.len(x) for x in cheader)
#     882 )
# --> 883 fmt_values = self.format_col(i)
#     884 fmt_values = _make_fixed_width(
#     885     fmt_values, self.justify, minimum=header_colwidth, adj=self.adj
#     886 )
#     888 max_len = max(max(self.adj.len(x) for x in fmt_values), header_colwidth)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\formats\format.py:897, in DataFrameFormatter.format_col(self, i)
#     895 frame = self.tr_frame
#     896 formatter = self._get_formatter(i)
# --> 897 return format_array(
#     898     frame.iloc[:, i]._values,
#     899     formatter,
#     900     float_format=self.float_format,
#     901     na_rep=self.na_rep,
#     902     space=self.col_space.get(frame.columns[i]),
#     903     decimal=self.decimal,
#     904     leading_space=self.index,
#     905 )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\formats\format.py:1328, in format_array(values, formatter, float_format, na_rep, digits, space, justify, decimal, leading_space, quoting)
#    1313     digits = get_option("display.precision")
#    1315 fmt_obj = fmt_klass(
#    1316     values,
#    1317     digits=digits,
#    (...)
#    1325     quoting=quoting,
#    1326 )
# -> 1328 return fmt_obj.get_result()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\formats\format.py:1359, in GenericArrayFormatter.get_result(self)
#    1358 def get_result(self) -> list[str]:
# -> 1359     fmt_values = self._format_strings()
#    1360     return _make_fixed_width(fmt_values, self.justify)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\formats\format.py:1422, in GenericArrayFormatter._format_strings(self)
#    1420 for i, v in enumerate(vals):
#    1421     if not is_float_type[i] and leading_space:
# -> 1422         fmt_values.append(f" {_format(v)}")
#    1423     elif is_float_type[i]:
#    1424         fmt_values.append(float_format(v))
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\formats\format.py:1402, in GenericArrayFormatter._format_strings.<locals>._format(x)
#    1399     return str(x)
#    1400 else:
#    1401     # object dtype
# -> 1402     return str(formatter(x))
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\formats\printing.py:232, in pprint_thing(thing, _nest_lvl, escape_chars, default_escapes, quote_strings, max_seq_items)
#     230     result = f"'{as_escaped_string(thing)}'"
#     231 else:
# --> 232     result = as_escaped_string(thing)
#     234 return result
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\formats\printing.py:208, in pprint_thing.<locals>.as_escaped_string(thing, escape_chars)
#     205 else:
#     206     escape_chars = escape_chars or ()
# --> 208 result = str(thing)
#     209 for c in escape_chars:
#     210     result = result.replace(c, translate[c])
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:1064, in DataFrame.__repr__(self)
#    1061     return buf.getvalue()
#    1063 repr_params = fmt.get_dataframe_repr_params()
# -> 1064 return self.to_string(**repr_params)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:1226, in DataFrame.to_string(self, buf, columns, col_space, header, index, na_rep, formatters, float_format, sparsify, index_names, justify, max_rows, max_cols, show_dimensions, decimal, line_width, min_rows, max_colwidth, encoding)
#    1193 """
#    1194 Render a DataFrame to a console-friendly tabular output.
#    1195 %(shared_params)s
#    (...)
#    1222 2     3     6
#    1223 """
#    1224 from pandas import option_context
# -> 1226 with option_context("display.max_colwidth", max_colwidth):
#    1227     formatter = fmt.DataFrameFormatter(
#    1228         self,
#    1229         columns=columns,
#    (...)
#    1243         decimal=decimal,
#    1244     )
#    1245     return fmt.DataFrameRenderer(formatter).to_string(
#    1246         buf=buf,
#    1247         encoding=encoding,
#    1248         line_width=line_width,
#    1249     )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_config\config.py:445, in option_context.__enter__(self)
#     442 self.undo = [(pat, _get_option(pat, silent=True)) for pat, val in self.ops]
#     444 for pat, val in self.ops:
# --> 445     _set_option(pat, val, silent=True)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_config\config.py:169, in _set_option(*args, **kwargs)
#     167 if silent:
#     168     with warnings.catch_warnings(record=True):
# --> 169         o.cb(key)
#     170 else:
#     171     o.cb(key)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\config_init.py:393, in _deprecate_negative_int_max_colwidth(key)
#     392 def _deprecate_negative_int_max_colwidth(key):
# --> 393     value = cf.get_option(key)
#     394     if value is not None and value < 0:
#     395         warnings.warn(
#     396             "Passing a negative integer is deprecated in version 1.0 and "
#     397             "will not be supported in future version. Instead, use None "
#    (...)
#     400             stacklevel=find_stack_level(),
#     401         )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_config\config.py:263, in CallableDynamicDoc.__call__(self, *args, **kwds)
#     262 def __call__(self, *args, **kwds) -> T:
# --> 263     return self.__func__(*args, **kwds)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_config\config.py:135, in _get_option(pat, silent)
#     134 def _get_option(pat: str, silent: bool = False) -> Any:
# --> 135     key = _get_single_key(pat, silent)
#     137     # walk the nested dict
#     138     root, k = _get_root(key)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_config\config.py:127, in _get_single_key(pat, silent)
#     124 key = keys[0]
#     126 if not silent:
# --> 127     _warn_if_deprecated(key)
#     129 key = _translate_key(key)
#     131 return key
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_config\config.py:658, in _warn_if_deprecated(key)
#     650 def _warn_if_deprecated(key: str) -> bool:
#     651     """
#     652     Checks if `key` is a deprecated option and if so, prints a warning.
#     653
#    (...)
#     656     bool - True if `key` is deprecated, False otherwise.
#     657     """
# --> 658     d = _get_deprecated_option(key)
#     659     if d:
#     660         if d.msg:
#
# RecursionError: maximum recursion depth exceeded
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\formatters.py:344, in BaseFormatter.__call__(self, obj)
#     342     method = get_real_method(obj, self.print_method)
#     343     if method is not None:
# --> 344         return method()
#     345     return None
#     346 else:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:1106, in DataFrame._repr_html_(self)
#    1084     show_dimensions = get_option("display.show_dimensions")
#    1086     formatter = fmt.DataFrameFormatter(
#    1087         self,
#    1088         columns=None,
#    (...)
#    1104         decimal=".",
#    1105     )
# -> 1106     return fmt.DataFrameRenderer(formatter).to_html(notebook=True)
#    1107 else:
#    1108     return None
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\formats\format.py:1110, in DataFrameRenderer.to_html(self, buf, encoding, classes, notebook, border, table_id, render_links)
#    1101 Klass = NotebookFormatter if notebook else HTMLFormatter
#    1103 html_formatter = Klass(
#    1104     self.fmt,
#    1105     classes=classes,
#    (...)
#    1108     render_links=render_links,
#    1109 )
# -> 1110 string = html_formatter.to_string()
#    1111 return save_to_buffer(string, buf=buf, encoding=encoding)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\formats\html.py:77, in HTMLFormatter.to_string(self)
#      76 def to_string(self) -> str:
# ---> 77     lines = self.render()
#      78     if any(isinstance(x, str) for x in lines):
#      79         lines = [str(x) for x in lines]
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\formats\html.py:632, in NotebookFormatter.render(self)
#     630 self.write("<div>")
#     631 self.write_style()
# --> 632 super().render()
#     633 self.write("</div>")
#     634 return self.elements
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\formats\html.py:83, in HTMLFormatter.render(self)
#      82 def render(self) -> list[str]:
# ---> 83     self._write_table()
#      85     if self.should_show_dimensions:
#      86         by = chr(215)  # ×
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\formats\html.py:258, in HTMLFormatter._write_table(self, indent)
#     255 if self.fmt.header or self.show_row_idx_names:
#     256     self._write_header(indent + self.indent_delta)
# --> 258 self._write_body(indent + self.indent_delta)
#     260 self.write("</table>", indent)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\formats\html.py:406, in HTMLFormatter._write_body(self, indent)
#     404 def _write_body(self, indent: int) -> None:
#     405     self.write("<tbody>", indent)
# --> 406     fmt_values = self._get_formatted_values()
#     408     # write values
#     409     if self.fmt.index and isinstance(self.frame.index, MultiIndex):
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\formats\html.py:596, in NotebookFormatter._get_formatted_values(self)
#     595 def _get_formatted_values(self) -> dict[int, list[str]]:
# --> 596     return {i: self.fmt.format_col(i) for i in range(self.ncols)}
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\formats\html.py:596, in <dictcomp>(.0)
#     595 def _get_formatted_values(self) -> dict[int, list[str]]:
# --> 596     return {i: self.fmt.format_col(i) for i in range(self.ncols)}
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\formats\format.py:897, in DataFrameFormatter.format_col(self, i)
#     895 frame = self.tr_frame
#     896 formatter = self._get_formatter(i)
# --> 897 return format_array(
#     898     frame.iloc[:, i]._values,
#     899     formatter,
#     900     float_format=self.float_format,
#     901     na_rep=self.na_rep,
#     902     space=self.col_space.get(frame.columns[i]),
#     903     decimal=self.decimal,
#     904     leading_space=self.index,
#     905 )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\formats\format.py:1328, in format_array(values, formatter, float_format, na_rep, digits, space, justify, decimal, leading_space, quoting)
#    1313     digits = get_option("display.precision")
#    1315 fmt_obj = fmt_klass(
#    1316     values,
#    1317     digits=digits,
#    (...)
#    1325     quoting=quoting,
#    1326 )
# -> 1328 return fmt_obj.get_result()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\formats\format.py:1359, in GenericArrayFormatter.get_result(self)
#    1358 def get_result(self) -> list[str]:
# -> 1359     fmt_values = self._format_strings()
#    1360     return _make_fixed_width(fmt_values, self.justify)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\formats\format.py:1422, in GenericArrayFormatter._format_strings(self)
#    1420 for i, v in enumerate(vals):
#    1421     if not is_float_type[i] and leading_space:
# -> 1422         fmt_values.append(f" {_format(v)}")
#    1423     elif is_float_type[i]:
#    1424         fmt_values.append(float_format(v))
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\formats\format.py:1402, in GenericArrayFormatter._format_strings.<locals>._format(x)
#    1399     return str(x)
#    1400 else:
#    1401     # object dtype
# -> 1402     return str(formatter(x))
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\formats\printing.py:232, in pprint_thing(thing, _nest_lvl, escape_chars, default_escapes, quote_strings, max_seq_items)
#     230     result = f"'{as_escaped_string(thing)}'"
#     231 else:
# --> 232     result = as_escaped_string(thing)
#     234 return result
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\formats\printing.py:208, in pprint_thing.<locals>.as_escaped_string(thing, escape_chars)
#     205 else:
#     206     escape_chars = escape_chars or ()
# --> 208 result = str(thing)
#     209 for c in escape_chars:
#     210     result = result.replace(c, translate[c])
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:1064, in DataFrame.__repr__(self)
#    1061     return buf.getvalue()
#    1063 repr_params = fmt.get_dataframe_repr_params()
# -> 1064 return self.to_string(**repr_params)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:1245, in DataFrame.to_string(self, buf, columns, col_space, header, index, na_rep, formatters, float_format, sparsify, index_names, justify, max_rows, max_cols, show_dimensions, decimal, line_width, min_rows, max_colwidth, encoding)
#    1226 with option_context("display.max_colwidth", max_colwidth):
#    1227     formatter = fmt.DataFrameFormatter(
#    1228         self,
#    1229         columns=columns,
#    (...)
#    1243         decimal=decimal,
#    1244     )
# -> 1245     return fmt.DataFrameRenderer(formatter).to_string(
#    1246         buf=buf,
#    1247         encoding=encoding,
#    1248         line_width=line_width,
#    1249     )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\formats\format.py:1136, in DataFrameRenderer.to_string(self, buf, encoding, line_width)
#    1133 from pandas.io.formats.string import StringFormatter
#    1135 string_formatter = StringFormatter(self.fmt, line_width=line_width)
# -> 1136 string = string_formatter.to_string()
#    1137 return save_to_buffer(string, buf=buf, encoding=encoding)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\formats\string.py:30, in StringFormatter.to_string(self)
#      29 def to_string(self) -> str:
# ---> 30     text = self._get_string_representation()
#      31     if self.fmt.should_show_dimensions:
#      32         text = "".join([text, self.fmt.dimensions_info])
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\formats\string.py:45, in StringFormatter._get_string_representation(self)
#      42 if self.fmt.frame.empty:
#      43     return self._empty_info_line
# ---> 45 strcols = self._get_strcols()
#      47 if self.line_width is None:
#      48     # no need to wrap around just print the whole frame
#      49     return self.adj.adjoin(1, *strcols)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\formats\string.py:36, in StringFormatter._get_strcols(self)
#      35 def _get_strcols(self) -> list[list[str]]:
# ---> 36     strcols = self.fmt.get_strcols()
#      37     if self.fmt.is_truncated:
#      38         strcols = self._insert_dot_separators(strcols)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\formats\format.py:617, in DataFrameFormatter.get_strcols(self)
#     613 def get_strcols(self) -> list[list[str]]:
#     614     """
#     615     Render a DataFrame to a list of columns (as lists of strings).
#     616     """
# --> 617     strcols = self._get_strcols_without_index()
#     619     if self.index:
#     620         str_index = self._get_formatted_index(self.tr_frame)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\formats\format.py:883, in DataFrameFormatter._get_strcols_without_index(self)
#     879 cheader = str_columns[i]
#     880 header_colwidth = max(
#     881     int(self.col_space.get(c, 0)), *(self.adj.len(x) for x in cheader)
#     882 )
# --> 883 fmt_values = self.format_col(i)
#     884 fmt_values = _make_fixed_width(
#     885     fmt_values, self.justify, minimum=header_colwidth, adj=self.adj
#     886 )
#     888 max_len = max(max(self.adj.len(x) for x in fmt_values), header_colwidth)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\formats\format.py:897, in DataFrameFormatter.format_col(self, i)
#     895 frame = self.tr_frame
#     896 formatter = self._get_formatter(i)
# --> 897 return format_array(
#     898     frame.iloc[:, i]._values,
#     899     formatter,
#     900     float_format=self.float_format,
#     901     na_rep=self.na_rep,
#     902     space=self.col_space.get(frame.columns[i]),
#     903     decimal=self.decimal,
#     904     leading_space=self.index,
#     905 )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\formats\format.py:1328, in format_array(values, formatter, float_format, na_rep, digits, space, justify, decimal, leading_space, quoting)
#    1313     digits = get_option("display.precision")
#    1315 fmt_obj = fmt_klass(
#    1316     values,
#    1317     digits=digits,
#    (...)
#    1325     quoting=quoting,
#    1326 )
# -> 1328 return fmt_obj.get_result()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\formats\format.py:1359, in GenericArrayFormatter.get_result(self)
#    1358 def get_result(self) -> list[str]:
# -> 1359     fmt_values = self._format_strings()
#    1360     return _make_fixed_width(fmt_values, self.justify)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\formats\format.py:1422, in GenericArrayFormatter._format_strings(self)
#    1420 for i, v in enumerate(vals):
#    1421     if not is_float_type[i] and leading_space:
# -> 1422         fmt_values.append(f" {_format(v)}")
#    1423     elif is_float_type[i]:
#    1424         fmt_values.append(float_format(v))
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\formats\format.py:1402, in GenericArrayFormatter._format_strings.<locals>._format(x)
#    1399     return str(x)
#    1400 else:
#    1401     # object dtype
# -> 1402     return str(formatter(x))
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\formats\printing.py:232, in pprint_thing(thing, _nest_lvl, escape_chars, default_escapes, quote_strings, max_seq_items)
#     230     result = f"'{as_escaped_string(thing)}'"
#     231 else:
# --> 232     result = as_escaped_string(thing)
#     234 return result
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\formats\printing.py:208, in pprint_thing.<locals>.as_escaped_string(thing, escape_chars)
#     205 else:
#     206     escape_chars = escape_chars or ()
# --> 208 result = str(thing)
#     209 for c in escape_chars:
#     210     result = result.replace(c, translate[c])
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:1064, in DataFrame.__repr__(self)
#    1061     return buf.getvalue()
#    1063 repr_params = fmt.get_dataframe_repr_params()
# -> 1064 return self.to_string(**repr_params)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:1245, in DataFrame.to_string(self, buf, columns, col_space, header, index, na_rep, formatters, float_format, sparsify, index_names, justify, max_rows, max_cols, show_dimensions, decimal, line_width, min_rows, max_colwidth, encoding)
#    1226 with option_context("display.max_colwidth", max_colwidth):
#    1227     formatter = fmt.DataFrameFormatter(
#    1228         self,
#    1229         columns=columns,
#    (...)
#    1243         decimal=decimal,
#    1244     )
# -> 1245     return fmt.DataFrameRenderer(formatter).to_string(
#    1246         buf=buf,
#    1247         encoding=encoding,
#    1248         line_width=line_width,
#    1249     )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\formats\format.py:1136, in DataFrameRenderer.to_string(self, buf, encoding, line_width)
#    1133 from pandas.io.formats.string import StringFormatter
#    1135 string_formatter = StringFormatter(self.fmt, line_width=line_width)
# -> 1136 string = string_formatter.to_string()
#    1137 return save_to_buffer(string, buf=buf, encoding=encoding)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\formats\string.py:30, in StringFormatter.to_string(self)
#      29 def to_string(self) -> str:
# ---> 30     text = self._get_string_representation()
#      31     if self.fmt.should_show_dimensions:
#      32         text = "".join([text, self.fmt.dimensions_info])
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\formats\string.py:45, in StringFormatter._get_string_representation(self)
#      42 if self.fmt.frame.empty:
#      43     return self._empty_info_line
# ---> 45 strcols = self._get_strcols()
#      47 if self.line_width is None:
#      48     # no need to wrap around just print the whole frame
#      49     return self.adj.adjoin(1, *strcols)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\formats\string.py:36, in StringFormatter._get_strcols(self)
#      35 def _get_strcols(self) -> list[list[str]]:
# ---> 36     strcols = self.fmt.get_strcols()
#      37     if self.fmt.is_truncated:
#      38         strcols = self._insert_dot_separators(strcols)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\formats\format.py:617, in DataFrameFormatter.get_strcols(self)
#     613 def get_strcols(self) -> list[list[str]]:
#     614     """
#     615     Render a DataFrame to a list of columns (as lists of strings).
#     616     """
# --> 617     strcols = self._get_strcols_without_index()
#     619     if self.index:
#     620         str_index = self._get_formatted_index(self.tr_frame)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\formats\format.py:883, in DataFrameFormatter._get_strcols_without_index(self)
#     879 cheader = str_columns[i]
#     880 header_colwidth = max(
#     881     int(self.col_space.get(c, 0)), *(self.adj.len(x) for x in cheader)
#     882 )
# --> 883 fmt_values = self.format_col(i)
#     884 fmt_values = _make_fixed_width(
#     885     fmt_values, self.justify, minimum=header_colwidth, adj=self.adj
#     886 )
#     888 max_len = max(max(self.adj.len(x) for x in fmt_values), header_colwidth)
#
#     [... skipping similar frames: DataFrame.__repr__ at line 1064 (161 times), GenericArrayFormatter._format_strings.<locals>._format at line 1402 (161 times), GenericArrayFormatter._format_strings at line 1422 (161 times), pprint_thing.<locals>.as_escaped_string at line 208 (161 times), format_array at line 1328 (161 times), DataFrameFormatter.format_col at line 897 (161 times), GenericArrayFormatter.get_result at line 1359 (161 times), pprint_thing at line 232 (161 times), StringFormatter._get_strcols at line 36 (160 times), DataFrameFormatter._get_strcols_without_index at line 883 (160 times), StringFormatter._get_string_representation at line 45 (160 times), DataFrameFormatter.get_strcols at line 617 (160 times), DataFrame.to_string at line 1245 (160 times), DataFrameRenderer.to_string at line 1136 (160 times), StringFormatter.to_string at line 30 (160 times)]
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:1245, in DataFrame.to_string(self, buf, columns, col_space, header, index, na_rep, formatters, float_format, sparsify, index_names, justify, max_rows, max_cols, show_dimensions, decimal, line_width, min_rows, max_colwidth, encoding)
#    1226 with option_context("display.max_colwidth", max_colwidth):
#    1227     formatter = fmt.DataFrameFormatter(
#    1228         self,
#    1229         columns=columns,
#    (...)
#    1243         decimal=decimal,
#    1244     )
# -> 1245     return fmt.DataFrameRenderer(formatter).to_string(
#    1246         buf=buf,
#    1247         encoding=encoding,
#    1248         line_width=line_width,
#    1249     )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\formats\format.py:1136, in DataFrameRenderer.to_string(self, buf, encoding, line_width)
#    1133 from pandas.io.formats.string import StringFormatter
#    1135 string_formatter = StringFormatter(self.fmt, line_width=line_width)
# -> 1136 string = string_formatter.to_string()
#    1137 return save_to_buffer(string, buf=buf, encoding=encoding)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\formats\string.py:30, in StringFormatter.to_string(self)
#      29 def to_string(self) -> str:
# ---> 30     text = self._get_string_representation()
#      31     if self.fmt.should_show_dimensions:
#      32         text = "".join([text, self.fmt.dimensions_info])
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\formats\string.py:45, in StringFormatter._get_string_representation(self)
#      42 if self.fmt.frame.empty:
#      43     return self._empty_info_line
# ---> 45 strcols = self._get_strcols()
#      47 if self.line_width is None:
#      48     # no need to wrap around just print the whole frame
#      49     return self.adj.adjoin(1, *strcols)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\formats\string.py:36, in StringFormatter._get_strcols(self)
#      35 def _get_strcols(self) -> list[list[str]]:
# ---> 36     strcols = self.fmt.get_strcols()
#      37     if self.fmt.is_truncated:
#      38         strcols = self._insert_dot_separators(strcols)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\formats\format.py:617, in DataFrameFormatter.get_strcols(self)
#     613 def get_strcols(self) -> list[list[str]]:
#     614     """
#     615     Render a DataFrame to a list of columns (as lists of strings).
#     616     """
# --> 617     strcols = self._get_strcols_without_index()
#     619     if self.index:
#     620         str_index = self._get_formatted_index(self.tr_frame)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\formats\format.py:883, in DataFrameFormatter._get_strcols_without_index(self)
#     879 cheader = str_columns[i]
#     880 header_colwidth = max(
#     881     int(self.col_space.get(c, 0)), *(self.adj.len(x) for x in cheader)
#     882 )
# --> 883 fmt_values = self.format_col(i)
#     884 fmt_values = _make_fixed_width(
#     885     fmt_values, self.justify, minimum=header_colwidth, adj=self.adj
#     886 )
#     888 max_len = max(max(self.adj.len(x) for x in fmt_values), header_colwidth)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\formats\format.py:897, in DataFrameFormatter.format_col(self, i)
#     895 frame = self.tr_frame
#     896 formatter = self._get_formatter(i)
# --> 897 return format_array(
#     898     frame.iloc[:, i]._values,
#     899     formatter,
#     900     float_format=self.float_format,
#     901     na_rep=self.na_rep,
#     902     space=self.col_space.get(frame.columns[i]),
#     903     decimal=self.decimal,
#     904     leading_space=self.index,
#     905 )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\formats\format.py:1328, in format_array(values, formatter, float_format, na_rep, digits, space, justify, decimal, leading_space, quoting)
#    1313     digits = get_option("display.precision")
#    1315 fmt_obj = fmt_klass(
#    1316     values,
#    1317     digits=digits,
#    (...)
#    1325     quoting=quoting,
#    1326 )
# -> 1328 return fmt_obj.get_result()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\formats\format.py:1359, in GenericArrayFormatter.get_result(self)
#    1358 def get_result(self) -> list[str]:
# -> 1359     fmt_values = self._format_strings()
#    1360     return _make_fixed_width(fmt_values, self.justify)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\formats\format.py:1422, in GenericArrayFormatter._format_strings(self)
#    1420 for i, v in enumerate(vals):
#    1421     if not is_float_type[i] and leading_space:
# -> 1422         fmt_values.append(f" {_format(v)}")
#    1423     elif is_float_type[i]:
#    1424         fmt_values.append(float_format(v))
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\formats\format.py:1402, in GenericArrayFormatter._format_strings.<locals>._format(x)
#    1399     return str(x)
#    1400 else:
#    1401     # object dtype
# -> 1402     return str(formatter(x))
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\formats\printing.py:232, in pprint_thing(thing, _nest_lvl, escape_chars, default_escapes, quote_strings, max_seq_items)
#     230     result = f"'{as_escaped_string(thing)}'"
#     231 else:
# --> 232     result = as_escaped_string(thing)
#     234 return result
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\formats\printing.py:208, in pprint_thing.<locals>.as_escaped_string(thing, escape_chars)
#     205 else:
#     206     escape_chars = escape_chars or ()
# --> 208 result = str(thing)
#     209 for c in escape_chars:
#     210     result = result.replace(c, translate[c])
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:1064, in DataFrame.__repr__(self)
#    1061     return buf.getvalue()
#    1063 repr_params = fmt.get_dataframe_repr_params()
# -> 1064 return self.to_string(**repr_params)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:1227, in DataFrame.to_string(self, buf, columns, col_space, header, index, na_rep, formatters, float_format, sparsify, index_names, justify, max_rows, max_cols, show_dimensions, decimal, line_width, min_rows, max_colwidth, encoding)
#    1224 from pandas import option_context
#    1226 with option_context("display.max_colwidth", max_colwidth):
# -> 1227     formatter = fmt.DataFrameFormatter(
#    1228         self,
#    1229         columns=columns,
#    1230         col_space=col_space,
#    1231         na_rep=na_rep,
#    1232         formatters=formatters,
#    1233         float_format=float_format,
#    1234         sparsify=sparsify,
#    1235         justify=justify,
#    1236         index_names=index_names,
#    1237         header=header,
#    1238         index=index,
#    1239         min_rows=min_rows,
#    1240         max_rows=max_rows,
#    1241         max_cols=max_cols,
#    1242         show_dimensions=show_dimensions,
#    1243         decimal=decimal,
#    1244     )
#    1245     return fmt.DataFrameRenderer(formatter).to_string(
#    1246         buf=buf,
#    1247         encoding=encoding,
#    1248         line_width=line_width,
#    1249     )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\formats\format.py:610, in DataFrameFormatter.__init__(self, frame, columns, col_space, header, index, na_rep, formatters, justify, float_format, sparsify, index_names, max_rows, min_rows, max_cols, show_dimensions, decimal, bold_rows, escape)
#     607 self.max_rows_fitted = self._calc_max_rows_fitted()
#     609 self.tr_frame = self.frame
# --> 610 self.truncate()
#     611 self.adj = get_adjustment()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\formats\format.py:801, in DataFrameFormatter.truncate(self)
#     798     self._truncate_horizontally()
#     800 if self.is_truncated_vertically:
# --> 801     self._truncate_vertically()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\formats\format.py:839, in DataFrameFormatter._truncate_vertically(self)
#     837 row_num = self.max_rows_fitted // 2
#     838 if row_num >= 1:
# --> 839     head = self.tr_frame.iloc[:row_num, :]
#     840     tail = self.tr_frame.iloc[-row_num:, :]
#     841     self.tr_frame = concat((head, tail))
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexing.py:1067, in _LocationIndexer.__getitem__(self, key)
#    1065     if self._is_scalar_access(key):
#    1066         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1067     return self._getitem_tuple(key)
#    1068 else:
#    1069     # we by definition only have the 0th axis
#    1070     axis = self.axis or 0
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexing.py:1563, in _iLocIndexer._getitem_tuple(self, tup)
#    1561 def _getitem_tuple(self, tup: tuple):
# -> 1563     tup = self._validate_tuple_indexer(tup)
#    1564     with suppress(IndexingError):
#    1565         return self._getitem_lowerdim(tup)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexing.py:873, in _LocationIndexer._validate_tuple_indexer(self, key)
#     871 for i, k in enumerate(key):
#     872     try:
# --> 873         self._validate_key(k, i)
#     874     except ValueError as err:
#     875         raise ValueError(
#     876             "Location based indexing can only have "
#     877             f"[{self._valid_types}] types"
#     878         ) from err
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexing.py:1449, in _iLocIndexer._validate_key(self, key, axis)
#    1448 def _validate_key(self, key, axis: int):
# -> 1449     if com.is_bool_indexer(key):
#    1450         if hasattr(key, "index") and isinstance(key.index, Index):
#    1451             if key.index.inferred_type == "integer":
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\common.py:124, in is_bool_indexer(key)
#      96 def is_bool_indexer(key: Any) -> bool:
#      97     """
#      98     Check whether `key` is a valid boolean indexer.
#      99
#    (...)
#     122         and convert to an ndarray.
#     123     """
# --> 124     if isinstance(key, (ABCSeries, np.ndarray, ABCIndex)) or (
#     125         is_array_like(key) and is_extension_array_dtype(key.dtype)
#     126     ):
#     127         if key.dtype == np.object_:
#     128             key_array = np.asarray(key)
#
# RecursionError: maximum recursion depth exceeded

# %%
df.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64
